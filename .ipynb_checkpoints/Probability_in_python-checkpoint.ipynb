# %% [markdown]
# # PROBABILITY IN PYTHON
# ---
# Here i'll be testing probability and statistics concepts which i learned during my college with the help of python

# %%
import numpy as np

# %% [markdown]
# ## Uniform outcome function
# $n$ = number of outcomes in the sample space \
# output = $m$ outcomes selected uniformly at random from 1 to $n$

# %%
def uniform(n,m):
    return.np.random.randint(1, n+1, size = m)
